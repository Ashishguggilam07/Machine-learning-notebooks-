# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/intership/teleCust1000t (1).csv")
df
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9    64.0   4       5     0.0
# 1         3      11   33        1        7   136.0   5       5     0.0
# 2         3      68   52        1       24   116.0   1      29     0.0
# 3         2      33   33        0       12    33.0   2       0     0.0
# 4         2      23   30        1        9    30.0   1       2     0.0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0    27.0   3       0     0.0
# 996       1       7   34        0        2    22.0   5       5     0.0
# 997       3      67   59        0       40   944.0   5      33     0.0
# 998       3      70   49        0       18    87.0   2      22     0.0
# 999       3      50   36        1        7    39.0   3       3     0.0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# 2         1       2        3
# 3         1       1        1
# 4         0       4        3
# ..      ...     ...      ...
# 995       1       3        1
# 996       1       1        1
# 997       1       1        4
# 998       1       1        3
# 999       1       3        2
#
# [1000 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   region   1000 non-null   int64
#  1   tenure   1000 non-null   int64
#  2   age      1000 non-null   int64
#  3   marital  1000 non-null   int64
#  4   address  1000 non-null   int64
#  5   income   1000 non-null   float64
#  6   ed       1000 non-null   int64
#  7   employ   1000 non-null   int64
#  8   retire   1000 non-null   float64
#  9   gender   1000 non-null   int64
#  10  reside   1000 non-null   int64
#  11  custcat  1000 non-null   int64
# dtypes: float64(2), int64(10)
# memory usage: 93.9 KB

# %%
df.describe()
# Out:
#           region       tenure          age      marital      address  \
# count  1000.0000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.0220    35.526000    41.684000     0.495000    11.551000
# std       0.8162    21.359812    12.558816     0.500225    10.086681
# min       1.0000     1.000000    18.000000     0.000000     0.000000
# 25%       1.0000    17.000000    32.000000     0.000000     3.000000
# 50%       2.0000    34.000000    40.000000     0.000000     9.000000
# 75%       3.0000    54.000000    51.000000     1.000000    18.000000
# max       3.0000    72.000000    77.000000     1.000000    55.000000
#
#             income           ed       employ       retire       gender  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     77.535000     2.671000    10.987000     0.047000     0.517000
# std     107.044165     1.222397    10.082087     0.211745     0.499961
# min       9.000000     1.000000     0.000000     0.000000     0.000000
# 25%      29.000000     2.000000     3.000000     0.000000     0.000000
# 50%      47.000000     3.000000     8.000000     0.000000     1.000000
# 75%      83.000000     4.000000    17.000000     0.000000     1.000000
# max    1668.000000     5.000000    47.000000     1.000000     1.000000
#
#             reside      custcat
# count  1000.000000  1000.000000
# mean      2.331000     2.487000
# std       1.435793     1.120306
# min       1.000000     1.000000
# 25%       1.000000     1.000000
# 50%       2.000000     3.000000
# 75%       3.000000     3.000000
# max       8.000000     4.000000

# %%
df.isna().sum()
# Out:
# region     0
# tenure     0
# age        0
# marital    0
# address    0
# income     0
# ed         0
# employ     0
# retire     0
# gender     0
# reside     0
# custcat    0
# dtype: int64

# %%
df["custcat"].value_counts()
# Out:
# 3    281
# 1    266
# 4    236
# 2    217
# Name: custcat, dtype: int64

# %%
df["gender"].value_counts()
# Out:
# 1    517
# 0    483
# Name: gender, dtype: int64

# %%
for coloum in df.columns:
  print(coloum)
  print(df[coloum].value_counts())
# Out:
# region
# 3    344
# 2    334
# 1    322
# Name: region, dtype: int64
# tenure
# 72    31
# 24    20
# 48    20
# 3     20
# 13    19
#       ..
# 36     7
# 2      7
# 47     7
# 21     6
# 63     6
# Name: tenure, Length: 72, dtype: int64
# age
# 33    39
# 39    35
# 35    34
# 31    32
# 34    32
# 37    31
# 40    28
# 42    28
# 30    26
# 52    25
# 36    25
# 54    24
# 45    24
# 43    24
# 27    24
# 48    24
# 46    24
# 41    24
# 51    23
# 25    23
# 50    23
# 28    22
# 26    21
# 55    21
# 47    21
# 32    21
# 38    21
# 24    20
# 57    20
# 44    20
# 29    19
# 53    19
# 49    18
# 23    16
# 22    15
# 59    14
# 63    12
# 56    11
# 61    11
# 60    11
# 64    10
# 20    10
# 58    10
# 62     9
# 21     8
# 66     7
# 68     6
# 69     6
# 65     6
# 67     5
# 19     4
# 76     3
# 70     3
# 75     2
# 71     1
# 72     1
# 74     1
# 77     1
# 18     1
# 73     1
# Name: age, dtype: int64
# marital
# 0    505
# 1    495
# Name: marital, dtype: int64
# address
# 1     68
# 2     66
# 4     61
# 3     61
# 0     56
# 7     53
# 5     50
# 9     41
# 8     39
# 10    38
# 12    36
# 6     36
# 13    33
# 19    29
# 14    24
# 15    24
# 11    23
# 17    22
# 20    20
# 18    20
# 21    20
# 27    16
# 23    15
# 22    15
# 16    14
# 26    12
# 25    12
# 28    12
# 24    12
# 30    11
# 29     8
# 31     6
# 34     6
# 32     5
# 38     5
# 33     5
# 43     3
# 37     3
# 40     3
# 44     3
# 39     3
# 36     2
# 35     2
# 41     1
# 49     1
# 45     1
# 48     1
# 42     1
# 46     1
# 55     1
# Name: address, dtype: int64
# income
# 25.0     24
# 26.0     22
# 41.0     22
# 33.0     20
# 46.0     19
#          ..
# 200.0     1
# 250.0     1
# 674.0     1
# 187.0     1
# 944.0     1
# Name: income, Length: 218, dtype: int64
# ed
# 2    287
# 4    234
# 3    209
# 1    204
# 5     66
# Name: ed, dtype: int64
# employ
# 0     106
# 1      66
# 2      59
# 5      54
# 4      52
# 3      50
# 7      48
# 6      44
# 9      39
# 8      38
# 11     34
# 12     32
# 10     30
# 15     30
# 13     28
# 21     22
# 20     20
# 22     20
# 18     20
# 19     19
# 25     17
# 16     17
# 17     16
# 24     14
# 23     14
# 14     13
# 27     10
# 35      9
# 31      9
# 29      9
# 30      8
# 26      8
# 33      7
# 28      5
# 37      5
# 34      4
# 36      4
# 32      3
# 39      3
# 43      3
# 40      3
# 44      2
# 41      2
# 45      2
# 38      1
# 47      1
# Name: employ, dtype: int64
# retire
# 0.0    953
# 1.0     47
# Name: retire, dtype: int64
# gender
# 1    517
# 0    483
# Name: gender, dtype: int64
# reside
# 1    375
# 2    272
# 3    138
# 4    120
# 5     60
# 6     29
# 7      4
# 8      2
# Name: reside, dtype: int64
# custcat
# 3    281
# 1    266
# 4    236
# 2    217
# Name: custcat, dtype: int64

# %%
df.shape
# Out:
# (1000, 12)

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot = True)

# %%
X=df[["region","tenure","age","marital","address","income","ed","employ","retire","gender","reside" ]]
y=df["custcat"]

# %%
X[0:5]
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside
# 0       2
# 1       6
# 2       2
# 3       1
# 4       4

# %%
y[0:5]
# Out:
# 0    1
# 1    4
# 2    3
# 3    1
# 4    3
# Name: custcat, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
print('Shape of X training set {}'.format(X_trainset.shape),'&',' Size of Y training set {}'.format(y_trainset.shape))
# Out:
# Shape of X training set (800, 11) &  Size of Y training set (800,)

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
clf
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
clf.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
pred = clf.predict(X_testset)

# %%
pred
# Out:
# array([1, 1, 1, 4, 1, 2, 3, 3, 3, 1, 3, 3, 3, 1, 2, 3, 3, 3, 1, 3, 2, 3,
#        2, 1, 2, 1, 4, 4, 2, 3, 1, 2, 3, 2, 3, 1, 4, 4, 3, 1, 1, 3, 3, 3,
#        3, 3, 4, 3, 2, 1, 2, 3, 3, 1, 2, 1, 2, 3, 1, 2, 1, 1, 1, 1, 3, 4,
#        2, 2, 1, 1, 2, 3, 3, 1, 2, 3, 4, 3, 3, 2, 4, 3, 2, 1, 1, 3, 4, 3,
#        2, 3, 1, 3, 3, 3, 3, 3, 1, 1, 2, 2, 4, 3, 3, 3, 3, 4, 2, 1, 2, 2,
#        2, 2, 2, 1, 2, 3, 3, 2, 2, 1, 3, 4, 3, 3, 3, 1, 3, 2, 1, 1, 3, 1,
#        1, 1, 1, 2, 1, 1, 3, 1, 4, 1, 3, 4, 4, 4, 3, 2, 4, 2, 2, 2, 2, 3,
#        3, 3, 3, 1, 2, 4, 3, 2, 3, 4, 2, 1, 1, 3, 3, 3, 3, 2, 3, 3, 1, 4,
#        1, 4, 3, 3, 2, 1, 4, 1, 3, 4, 3, 1, 4, 3, 1, 4, 3, 1, 3, 4, 3, 1,
#        3, 4])

# %%
print(pred[0:5])
print(y_testset[0:5])
# Out:
# [1 1 1 4 1]
# 642    3
# 762    3
# 909    1
# 199    4
# 586    1
# Name: custcat, dtype: int64

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, pred))
# Out:
# DecisionTrees's Accuracy:  0.38

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
print("classificationreport")
print(classification_report(y_testset,pred,digits=2))
print("confusion marix")
print(confusion_matrix(y_testset,pred))
from sklearn.metrics import jaccard_score
print("jaccob index")
print(jaccard_score(y_testset,pred, average='weighted'))
# Out:
# classificationreport
#               precision    recall  f1-score   support
#
#            1       0.39      0.42      0.40        50
#            2       0.33      0.33      0.33        43
#            3       0.41      0.52      0.46        60
#            4       0.36      0.21      0.27        47
#
#     accuracy                           0.38       200
#    macro avg       0.37      0.37      0.36       200
# weighted avg       0.38      0.38      0.37       200
#
# confusion marix
# [[21  6 17  6]
#  [10 14 10  9]
#  [18  8 31  3]
#  [ 5 15 17 10]]
# jaccob index
# 0.23063549068067143

# %% [markdown]
# SVM

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear')
clf.fit(X_trainset, y_trainset)
y_pred = clf.predict(X_testset)
print("\n Predicted Values:\n")
print(y_pred [0:5])
from sklearn.metrics import classification_report, confusion_matrix
import itertools
print("classificationreport")
print(classification_report(y_testset,pred,digits=2))
print("confusion marix")
print(confusion_matrix(y_testset,pred))
from sklearn.metrics import jaccard_score
print("jaccob index")
print(jaccard_score(y_testset,pred, average='weighted'))
# Out:
#  Predicted Values:
#
# [1 1 1 4 1]
# classificationreport
#               precision    recall  f1-score   support
#
#            1       0.39      0.42      0.40        50
#            2       0.33      0.33      0.33        43
#            3       0.41      0.52      0.46        60
#            4       0.36      0.21      0.27        47
#
#     accuracy                           0.38       200
#    macro avg       0.37      0.37      0.36       200
# weighted avg       0.38      0.38      0.37       200
#
# confusion marix
# [[21  6 17  6]
#  [10 14 10  9]
#  [18  8 31  3]
#  [ 5 15 17 10]]
# jaccob index
# 0.23063549068067143

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
clf=KNeighborsClassifier(n_neighbors=5)
clf.fit(X_trainset, y_trainset)
y_pred = clf.predict(X_testset)
print("\n Predicted Values:\n")
print(y_pred [0:5])
from sklearn.metrics import classification_report, confusion_matrix
import itertools
print("classificationreport")
print(classification_report(y_testset,pred,digits=2))
print("confusion marix")
print(confusion_matrix(y_testset,pred))
from sklearn.metrics import jaccard_score
print("jaccob index")
print(jaccard_score(y_testset,pred, average='weighted'))
# Out:
#  Predicted Values:
#
# [1 4 1 4 2]
# classificationreport
#               precision    recall  f1-score   support
#
#            1       0.39      0.42      0.40        50
#            2       0.33      0.33      0.33        43
#            3       0.41      0.52      0.46        60
#            4       0.36      0.21      0.27        47
#
#     accuracy                           0.38       200
#    macro avg       0.37      0.37      0.36       200
# weighted avg       0.38      0.38      0.37       200
#
# confusion marix
# [[21  6 17  6]
#  [10 14 10  9]
#  [18  8 31  3]
#  [ 5 15 17 10]]
# jaccob index
# 0.23063549068067143

# %% [markdown]
# random forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_trainset, y_trainset)
y_pred = clf.predict(X_testset)
print("\n Predicted Values:\n")
print(y_pred [0:5])
from sklearn.metrics import classification_report, confusion_matrix
import itertools
print("classificationreport")
print(classification_report(y_testset,pred,digits=2))
print("confusion marix")
print(confusion_matrix(y_testset,pred))
from sklearn.metrics import jaccard_score
print("jaccob index")
print(jaccard_score(y_testset,pred, average='weighted'))
# Out:
#  Predicted Values:
#
# [1 2 1 3 1]
# classificationreport
#               precision    recall  f1-score   support
#
#            1       0.39      0.42      0.40        50
#            2       0.33      0.33      0.33        43
#            3       0.41      0.52      0.46        60
#            4       0.36      0.21      0.27        47
#
#     accuracy                           0.38       200
#    macro avg       0.37      0.37      0.36       200
# weighted avg       0.38      0.38      0.37       200
#
# confusion marix
# [[21  6 17  6]
#  [10 14 10  9]
#  [18  8 31  3]
#  [ 5 15 17 10]]
# jaccob index
# 0.23063549068067143
